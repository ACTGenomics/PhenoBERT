# %%
from ragflow_sdk import RAGFlow
import pandas as pd

# %%
base_url='http://192.168.5.85:9380'
RAGFLOW_API_KEY='ragflow-Y5ZjA5YWY2MzU0ZDExZjBhYjkwMDI0Mm'

# %%
MODEL_NAME='gemini-2.5-flash-lite-preview-06-17'

# %%
TEMPERATURE=0.2
TOP_P=0.3
PRESENCE_PENALTY=0.4
FREQUENCY_PENALTY=0.7

# %%
# Retrive config
RERANKER='BAAI/bge-reranker-v2-m3___Huggingface'
VECTOR_SIMILARITY_WEIGHT=0.9
SIMILARITY_THRESHOLD=0.2
EMBEDDING_TOP_K=100
RERANKER_TOP_K=100

# %%
def create_prompt_templates():
    bio_prompt_text = f"""Given a paragraph of patient information from discharge note, please extract the phenotype about this patient only.

Check the Human Phenotype Ontology (HPO) database to determine the phenotype.

Only output the extracted phenotypes.

Use the format: {{‘HPO’: ‘HP:0000000’, ‘Phenotype’: ‘Phenotype description’}}

Patient information:"""
    return bio_prompt_text

# %%
llm_config = {
    "model_name": MODEL_NAME,
    "temperature": TEMPERATURE,
    "top_p":TOP_P,
    "presence_penalty":PRESENCE_PENALTY,
    "frequency_penalty": FREQUENCY_PENALTY,
    #"max_tokens": 7000 # remove to debug
}

# %%
rag_client = RAGFlow(api_key=RAGFLOW_API_KEY, base_url=base_url)
rag_client.delete_chats()

# %%
import time
import random
import uuid

def create_chat(#clinical_summary: str,
                rerank_id, 
            vector_similarity_weight: float = 0.3, similarity_threshold: float = 0.2, 
            embedding_top_k: int = 100, reranker_top_k: int = 100):

        
    # Get prompt templates
    bio_prompt_text= create_prompt_templates()
    
    # Create prompt configuration based on type
    prompt_config = {
        "prompt": bio_prompt_text,
        "show_quote": False,
        "top_n": 1,
        "similarity_threshold": similarity_threshold,
        "keywords_similarity_weight": 1-vector_similarity_weight,
        "rerank_model": rerank_id,
        "top_k": 100,
        "variables": [{"key": "knowledge", "optional": True}],
        "empty_response": None,
    }
    unique_id = str(uuid.uuid4())
    # Create a unique name for the chat
    unique_name = f"phenotype_extractor_{int(time.time())}_{random.randint(1000, 99999999)}_{unique_id}"

    try:
        # Create the chat session
        assistant = rag_client.create_chat(
            name=unique_name,
        )
        
        update_data = {
            "llm": llm_config,
            "prompt": prompt_config
        }
        assistant.update(update_data)
        
        # 創建 session
        session = assistant.create_session(f'phenotype_type_summary_assistant_{int(time.time())}')
        return session
    except Exception as e:
        print(f"Error creating chat session: {str(e)}")
        raise

# %%
import json
import ast
import re
def output_json_formater(raw_string, output_type='json'):
    """
    一個強健的、有彈性的函式，用於解析來自 LLM 的 HPO 表型列表。
    它可以處理多種格式變化和單行錯誤，而不會導致整個函式崩潰。
    """
    # 1. 基本驗證：確保輸入不是空的
    if not raw_string or not isinstance(raw_string, str):
        return {} if output_type == 'json' else '-'

    # 2. 清洗字串：替換各種智慧引號，這是處理 LLM 輸出的關鍵第一步
    clean_string = raw_string.replace("’", "'").replace("‘", "'")
    clean_string = clean_string.replace('“', '"').replace('”', '"')

    # 3. 提取所有類字典結構：使用正規表達式尋找所有被 `{...}` 包裹的內容
    #    這是比按行分割更強大的方法，可以忽略行前綴和周圍的文字
    dict_strings = re.findall(r'\{.*?\}', clean_string)

    if not dict_strings:
        return {} if output_type == 'json' else '-'

    # 4. 逐一解析並收集有效資料
    valid_data_list = []
    for dict_str in dict_strings:
        try:
            # ast.literal_eval 是安全的，但仍需錯誤處理
            data = ast.literal_eval(dict_str)
            # 確保解析出來的是字典且包含必要欄位
            if isinstance(data, dict) and 'HPO' in data and 'Phenotype' in data:
                valid_data_list.append(data)
        except (ValueError, SyntaxError, MemoryError):
            # 如果單一項目解析失敗，印出提示並繼續處理下一個，而不是讓整個函式崩潰
            # print(f"Skipping malformed entry: {dict_str}")
            continue
    
    # 如果沒有任何一個項目被成功解析
    if not valid_data_list:
        return {} if output_type == 'json' else '-'

    # 5. 轉換成最終格式
    result_dict = {item['HPO']: item['Phenotype'] for item in valid_data_list}
    
    if output_type == 'json':
        return result_dict
    
    if output_type == 'string':
        # 直接從字典的鍵創建列表，因為鍵是唯一的
        return ','.join(result_dict.keys())
        
    # 預留一個預設回傳值
    return result_dict

# %%
import google.generativeai as genai

# 設定你的 API 金鑰
genai.configure(api_key="AIzaSyDcSzeBZQ8lvCkpl2693ogJ4HwFUCZ7MxQ")

import google.generativeai as genai
from typing import List, Optional

def gemini_price_counter(
    prompt: str,
    input_list: Optional[List[str]] = None,
    output_list: Optional[List[str]] = None,
    input_token_price_per_million: float = 0.1,
    output_token_price_per_million: float = 0.4,
    model_name: str = 'gemini-1.5-flash'
) -> dict:
    """
    計算 Gemini API 的 token 用量和預估費用。

    Args:
        prompt (str): 主要的提示字串。
        input_list (Optional[List[str]]): 額外的輸入內容列表。
        output_list (Optional[List[str]]): 模型回應的輸出內容列表。
        input_token_price_per_million (float): 每百萬個輸入 token 的價格 (美元)。
        output_token_price_per_million (float): 每百萬個輸出 token 的價格 (美元)。
        model_name (str): 用來計算 token 的模型名稱。

    Returns:
        dict: 包含 total_tokens 和 total_cost 的字典。
    """
    if input_list is None:
        input_list = []
    if output_list is None:
        output_list = []

    model = genai.GenerativeModel(model_name)
    total_input_tokens = 0
    total_output_tokens = 0

    # 處理輸入 token：將所有輸入內容合併為一個完整的請求
    combined_input_text = prompt + " ".join(input_list)
    total_input_tokens = model.count_tokens(combined_input_text).total_tokens

    # 處理輸出 token
    if output_list:
        combined_output_text = " ".join(output_list)
        total_output_tokens = model.count_tokens(combined_output_text).total_tokens

    # 計算總費用
    input_cost = (total_input_tokens / 1_000_000) * input_token_price_per_million
    output_cost = (total_output_tokens / 1_000_000) * output_token_price_per_million
    total_cost = input_cost + output_cost

    return {
        "total_input_tokens": total_input_tokens,
        "total_output_tokens": total_output_tokens,
        "total_tokens": total_input_tokens + total_output_tokens,
        "total_cost_usd": total_cost,
        "input_cost_usd": input_cost,
        "output_cost_usd": output_cost
    }

# --- 使用範例 ---
# if __name__ == "__main__":
#     main_prompt = "請幫我總結以下文字："
#     input_data = [
#         "Python 是一種高階、直譯式、通用且功能強大的程式語言。",
#         "Google Cloud 提供一系列雲端運算服務。"
#     ]
#     output_data = [
#         "Python 是一種功能強大的高階程式語言，而 Google Cloud 則提供多樣的雲端服務。"
#     ]

#     price_info = gemini_price_counter(
#         prompt=main_prompt,
#         input_list=input_data,
#         output_list=output_data,
#     )

#     print(f"總輸入 token 數: {price_info['total_input_tokens']}")
#     print(f"總輸出 token 數: {price_info['total_output_tokens']}")
#     print(f"總費用 (USD): {price_info['total_cost_usd']:.8f}")

# %%
clinical_summary = 'A a female shows clinical features including High forehead, Bulging forehead, Broad forehead, Arched eyebrows, small hypothenar eminence, Dropped arches, Abnormality of the reproductive system, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Wide-set eyes, Eye folds, Bushy eyebrows, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, long philtrum, short philtrum, smooth philtrum, deep philtrum, Thin red part of the upper lip, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, Broad thumb, Club feet, Long big toe, Bunion, Toe curvature, and umbilical hernia, consistent with a diagnosis of jacobsen syndrome (omim:147791).'

# %%
# # Retrive config
# RERANKER='BAAI/bge-reranker-v2-m3___Huggingface'
# VECTOR_SIMILARITY_WEIGHT=0.9
# SIMILARITY_THRESHOLD=0.2
# EMBEDDING_TOP_K=100
# RERANKER_TOP_K=100

# %%
# session = create_chat(RERANKER, VECTOR_SIMILARITY_WEIGHT, 
#     SIMILARITY_THRESHOLD, EMBEDDING_TOP_K, RERANKER_TOP_K)

# %%
import threading
import concurrent.futures
from functools import partial
from tqdm.notebook import tqdm
import json

# 假設這些是您既有的函式和變數
# from some_module import create_chat, output_json_formater, RERANKER, ...

# -----------------
# 步驟 1: 建立全域的執行緒安全快取
# -----------------
# 這是我們用來儲存已處理結果的地方。
# 使用 threading.Lock 來確保在讀取或寫入快取時不會有兩個執行緒同時操作，造成資料混亂。
output_cache = {}
cache_lock = threading.Lock()

# -----------------
# 步驟 2: 建立 Thread-Local 儲存物件
# -----------------
thread_local_data = threading.local()

# -----------------
# 步驟 3: 建立新的 Worker 函式，整合 Session 重複使用和快取邏輯
# -----------------
def worker_with_cache(summary, output_type):
    """
    這個 worker 函式會為每個執行緒創建並重複使用一個 session。
    並在處理前，先檢查快取中是否已有結果。
    """
    # 執行緒安全的快取檢查
    with cache_lock:
        if summary in output_cache:
            # 如果快取中已有結果，直接回傳
            print(f"快取命中！跳過處理：'{summary[:30]}...'")
            return output_cache[summary]

    # 檢查當前這個執行緒是否已經初始化過 session
    if not hasattr(thread_local_data, 'session'):
        print(f"執行緒 {threading.get_ident()}: 正在初始化新的 session...")
        thread_local_data.session = create_chat(
            RERANKER,
            VECTOR_SIMILARITY_WEIGHT,
            SIMILARITY_THRESHOLD,
            EMBEDDING_TOP_K,
            RERANKER_TOP_K
        )

    session = thread_local_data.session

    try:
        stream_response = []
        for ans in session.ask(summary, stream=True):
            stream_response.append(ans)

        if stream_response:
            last_response = stream_response[-1]
            result = output_json_formater(last_response.content, output_type=output_type)
            time.sleep(1)
        else:
            result = '-'
    
    except Exception as e:
        print(f"執行緒 {threading.get_ident()}: 處理 '{summary[:30]}...' 時發生錯誤: {e}")
        result = None

    # 將結果儲存到快取中
    # 在寫入快取時也需要鎖定
    with cache_lock:
        output_cache[summary] = result

    return result

# -----------------
# 步驟 4: 修改主函式以適配新的 Worker
# -----------------
def process_summaries_in_parallel(summaries_list, output_type='string', max_workers=10):
    """
    使用多執行緒平行處理臨床摘要列表，並為每個執行緒重複使用 session。
    """
    # 在開始處理前，你可以選擇性地檢查快取，排除已處理過的項目
    # 但在 worker 內部檢查通常更高效，因為它能處理重複的輸入。

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        task_function = partial(worker_with_cache, output_type=output_type)
        results_iterator = executor.map(task_function, summaries_list)
        
        # 使用 tqdm 顯示進度
        results = list(tqdm(results_iterator, total=len(summaries_list), desc="處理臨床摘要中"))

    return results

# %%
output_cache = {key: value for key, value in output_cache.items() if value != '-'}

# %%
len(output_cache)
# Out:
# 888

# %%
output_cache
# Out:
# {'A a female shows clinical features including High forehead, Bulging forehead, Broad forehead, Arched eyebrows, small hypothenar eminence, Dropped arches, Abnormality of the reproductive system, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Wide-set eyes, Eye folds, Bushy eyebrows, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, long philtrum, short philtrum, smooth philtrum, deep philtrum, Thin red part of the upper lip, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, Broad thumb, Club feet, Long big toe, Bunion, Toe curvature, and umbilical hernia, consistent with a diagnosis of jacobsen syndrome (omim:147791).': 'HP:0000218,HP:0011191,HP:0011192,HP:0000597,HP:0010473,HP:0001801,HP:0000119,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000598,HP:0000599,HP:0000330,HP:0000308,HP:0000508,HP:0000490,HP:0000539,HP:0000545,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000343,HP:0000344,HP:0000345,HP:0000346,HP:0000221,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0001190,HP:0001771,HP:0001821,HP:0001825,HP:0001826,HP:0001507',
#  'This case involves A a female diagnosed with jacobsen syndrome (omim:147791), exhibiting High forehead, Bulging forehead, Broad forehead, Circular face, Broad face, Wide-set eyes, Eye folds, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Nasal tip, upturned, low hanging columella, short philtrum, smooth philtrum, Thin red part of the upper lip, Apple cheeks, small hypothenar eminence, Broad thumb, Dropped arches, Bunion, Toe curvature, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Bushy eyebrows, Arched eyebrows, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Decreased size of nasal tip, long philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, Club feet, Long big toe, Short toe, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000599,HP:0000330,HP:0000308,HP:0000508,HP:0000453,HP:0000456,HP:0000344,HP:0000345,HP:0000221,HP:0000299,HP:0010473,HP:0001190,HP:0001801,HP:0001825,HP:0001826,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000598,HP:0000597,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000454,HP:0000343,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0001771,HP:0001821,HP:0001827,HP:0001507,HP:0000119',
#  'Circular face, broad face, wide-set eyes, eye folds, sparse eyebrow, drooping upper eyelid, short philtrum, low set ears, ears rotated toward back of head, small thenar eminence, small hypothenar eminence, dropped arches, long big toe, bunion, short toe, triangular head shape, flat back of skull, prominent back of the head, high forehead, bulging forehead, broad forehead, decreased width of the forehead, flat face, face with broad temples and narrow chin, bushy eyebrows, arched eyebrows, increased length of eyelashes, downward slanting of the opening between the eyelids, deep set eye, bulging eye, cat eye, clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, broad flat nasal bridge, elongated nose, bulbous nose, nasal tip, upturned, decreased size of nasal tip, low hanging columella, long philtrum, smooth philtrum, deep philtrum, thin red part of the upper lip, full upper lip, decreased volume of lower lip, full lower lip, drooping lower lip, elevated palate, cleft palate, abnormality of dental shape, apple cheeks, small ears, conductive deafness, low frontal hairline, brittle hair, decreased length of neck, neck webbing, broad thumb, club feet, toe curvature, umbilical hernia, and abnormality of the reproductive system are observed in A a female with jacobsen syndrome (omim:147791).': 'HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000599,HP:0000508,HP:0000344,HP:0000369,HP:0000371,HP:0010474,HP:0010473,HP:0001801,HP:0001821,HP:0001825,HP:0001827,HP:0000278,HP:0000215,HP:0000216,HP:0000218,HP:0011191,HP:0011192,HP:0011193,HP:0000256,HP:0002094,HP:0000598,HP:0000597,HP:0000330,HP:0000308,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000343,HP:0000345,HP:0000346,HP:0000221,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0001190,HP:0001771,HP:0001826,HP:0001507,HP:0000119',
#  'A a female shows clinical features including Triangular head shape, High forehead, Broad forehead, Circular face, Broad face, Wide-set eyes, Eye folds, Downward slanting of the opening between the eyelids, Drooping upper eyelid, esodeviation, Broad flat nasal bridge, Bulbous nose, long philtrum, smooth philtrum, Thin red part of the upper lip, Small ears, Low set ears, small thenar eminence, small hypothenar eminence, Club feet, Bunion, Short toe, Toe curvature, Abnormality of the reproductive system, Flat back of skull, Prominent back of the head, Bulging forehead, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Bushy eyebrows, Sparse eyebrow, Arched eyebrows, Increased length of eyelashes, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, exodeviation, Elongated nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, short philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, Broad thumb, Dropped arches, Long big toe, and umbilical hernia, consistent with a diagnosis of jacobsen syndrome (omim:147791).': 'HP:0000278,HP:0000218,HP:0011192,HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000308,HP:0000508,HP:0000555,HP:0000426,HP:0000448,HP:0000343,HP:0000345,HP:0000221,HP:0000368,HP:0000369,HP:0010474,HP:0010473,HP:0001771,HP:0001825,HP:0001827,HP:0001826,HP:0000119,HP:0000215,HP:0000216,HP:0011191,HP:0011193,HP:0000256,HP:0002094,HP:0000598,HP:0000599,HP:0000597,HP:0000330,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000556,HP:0000431,HP:0000453,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0001190,HP:0001801,HP:0001821,HP:0001507',
#  'A a male shows clinical features including High forehead, Broad forehead, Circular face, Broad face, Wide-set eyes, Eye folds, Sparse eyebrow, Downward slanting of the opening between the eyelids, Drooping upper eyelid, exodeviation, long philtrum, Abnormal dentition, Dropped arches, Long big toe, Toe curvature, umbilical hernia, Triangular head shape, Flat back of skull, Prominent back of the head, Bulging forehead, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Bushy eyebrows, Arched eyebrows, Increased length of eyelashes, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, short philtrum, smooth philtrum, deep philtrum, Thin red part of the upper lip, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Club feet, Bunion, Short toe, and Abnormality of the reproductive system, consistent with a diagnosis of jacobsen syndrome (omim:147791).': 'HP:0000218,HP:0011192,HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000599,HP:0000308,HP:0000508,HP:0000556,HP:0000343,HP:0000685,HP:0001801,HP:0001821,HP:0001826,HP:0001507,HP:0000278,HP:0000215,HP:0000216,HP:0011191,HP:0011193,HP:0000256,HP:0002094,HP:0000598,HP:0000597,HP:0000330,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000344,HP:0000345,HP:0000346,HP:0000221,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001771,HP:0001825,HP:0001827,HP:0000119',
#  'This case involves A a female diagnosed with jacobsen syndrome (omim:147791), exhibiting Triangular head shape, Flat back of skull, High forehead, Bulging forehead, Broad forehead, Flat face, Broad face, Wide-set eyes, Eye folds, Sparse eyebrow, Arched eyebrows, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Bulging eye, exodeviation, Broad flat nasal bridge, Nasal tip, upturned, long philtrum, smooth philtrum, Thin red part of the upper lip, Apple cheeks, Low set ears, Ears rotated toward back of head, Decreased length of neck, Neck webbing, Dropped arches, Prominent back of the head, Decreased width of the forehead, Face with broad temples and narrow chin, Circular face, Bushy eyebrows, Deep set eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Elongated nose, Bulbous nose, Decreased size of nasal tip, low hanging columella, short philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Small ears, Conductive deafness, Low frontal hairline, Brittle hair, small thenar eminence, small hypothenar eminence, Broad thumb, Club feet, Long big toe, Bunion, Short toe, Toe curvature, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000278,HP:0000215,HP:0000218,HP:0011191,HP:0011192,HP:0000256,HP:0000255,HP:0000324,HP:0000325,HP:0000599,HP:0000597,HP:0000330,HP:0000308,HP:0000508,HP:0000539,HP:0000556,HP:0000426,HP:0000453,HP:0000343,HP:0000345,HP:0000221,HP:0000299,HP:0000369,HP:0000371,HP:0000131,HP:0000133,HP:0001801,HP:0000216,HP:0011193,HP:0002094,HP:0000257,HP:0000598,HP:0000490,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000431,HP:0000448,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000368,HP:0001254,HP:0000270,HP:0002224,HP:0010474,HP:0010473,HP:0001190,HP:0001771,HP:0001821,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'A a female with jacobsen syndrome (omim:147791) who presents with High forehead, Bulging forehead, Broad forehead, Circular face, Broad face, Wide-set eyes, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Broad flat nasal bridge, long philtrum, smooth philtrum, Thin red part of the upper lip, Small ears, small hypothenar eminence, Dropped arches, Long big toe, Bunion, Short toe, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Eye folds, Bushy eyebrows, Arched eyebrows, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, short philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, Broad thumb, Club feet, Toe curvature, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000257,HP:0000255,HP:0000324,HP:0000599,HP:0000330,HP:0000308,HP:0000508,HP:0000426,HP:0000343,HP:0000345,HP:0000221,HP:0000368,HP:0010473,HP:0001801,HP:0001821,HP:0001825,HP:0001827,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000325,HP:0000598,HP:0000597,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0001190,HP:0001771,HP:0001826,HP:0001507,HP:0000119',
#  'A a female with jacobsen syndrome (omim:147791) who presents with High forehead, Bulging forehead, Broad forehead, Wide-set eyes, Eye folds, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, low hanging columella, short philtrum, Thin red part of the upper lip, Small ears, Dropped arches, Long big toe, Toe curvature, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Bushy eyebrows, Arched eyebrows, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, long philtrum, smooth philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Club feet, Bunion, Short toe, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000324,HP:0000325,HP:0000599,HP:0000330,HP:0000308,HP:0000508,HP:0000456,HP:0000344,HP:0000221,HP:0000368,HP:0001801,HP:0001821,HP:0001825,HP:0001827,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000598,HP:0000597,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000345,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001771,HP:0001507,HP:0000119',
#  'Decreased width of the forehead, wide-set eyes, eye folds, bushy eyebrows, increased length of eyelashes, downward slanting of the opening between the eyelids, drooping upper eyelid, broad flat nasal bridge, bulbous nose, long philtrum, smooth philtrum, thin red part of the upper lip, abnormality of dental shape, small ears, low frontal hairline, decreased length of neck, small thenar eminence, small hypothenar eminence, dropped arches, long big toe, bunion, toe curvature, abnormality of the reproductive system, triangular head shape, flat back of skull, prominent back of the head, high forehead, bulging forehead, broad forehead, flat face, face with broad temples and narrow chin, circular face, broad face, sparse eyebrow, arched eyebrows, deep set eye, bulging eye, cat eye, clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, elongated nose, nasal tip, upturned, decreased size of nasal tip, low hanging columella, short philtrum, deep philtrum, full upper lip, decreased volume of lower lip, full lower lip, drooping lower lip, elevated palate, cleft palate, apple cheeks, low set ears, ears rotated toward back of head, conductive deafness, brittle hair, neck webbing, broad thumb, club feet, short toe, and umbilical hernia are observed in A a male with jacobsen syndrome (omim:147791).': 'HP:0011193,HP:0000324,HP:0000325,HP:0000598,HP:0000330,HP:0000308,HP:0000508,HP:0000426,HP:0000448,HP:0000343,HP:0000345,HP:0000221,HP:0000694,HP:0000368,HP:0000270,HP:0000131,HP:0010474,HP:0010473,HP:0001801,HP:0001821,HP:0001825,HP:0001826,HP:0000119,HP:0000278,HP:0000215,HP:0000216,HP:0000218,HP:0011191,HP:0011192,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000599,HP:0000597,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000431,HP:0000453,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000299,HP:0000369,HP:0000371,HP:0001254,HP:0002224,HP:0000133,HP:0001190,HP:0001771,HP:0001827,HP:0001507',
#  'A a female with jacobsen syndrome (omim:147791) who presents with High forehead, Bulging forehead, Broad forehead, Broad face, Wide-set eyes, Eye folds, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Broad flat nasal bridge, smooth philtrum, Thin red part of the upper lip, Small ears, Conductive deafness, small thenar eminence, small hypothenar eminence, Long big toe, Toe curvature, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Bushy eyebrows, Arched eyebrows, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, long philtrum, short philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Low set ears, Ears rotated toward back of head, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, Broad thumb, Dropped arches, Club feet, Bunion, Short toe, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000255,HP:0000324,HP:0000325,HP:0000599,HP:0000330,HP:0000308,HP:0000508,HP:0000426,HP:0000345,HP:0000221,HP:0000368,HP:0001254,HP:0010474,HP:0010473,HP:0001821,HP:0001826,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000598,HP:0000597,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000343,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000369,HP:0000371,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0001190,HP:0001801,HP:0001771,HP:0001825,HP:0001507,HP:0000119',
#  'A a female shows clinical features including Downward slanting of the opening between the eyelids, Broad flat nasal bridge, Elongated nose, Bulbous nose, Thin red part of the upper lip, Full lower lip, Apple cheeks, Small ears, Low set ears, Dropped arches, Triangular head shape, Flat back of skull, Prominent back of the head, High forehead, Bulging forehead, Broad forehead, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Eye folds, Bushy eyebrows, Sparse eyebrow, Arched eyebrows, Increased length of eyelashes, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, long philtrum, short philtrum, smooth philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Club feet, Long big toe, Bunion, Short toe, Toe curvature, umbilical hernia, and Abnormality of the reproductive system, consistent with a diagnosis of jacobsen syndrome (omim:147791).': 'HP:0000308,HP:0000426,HP:0000431,HP:0000448,HP:0000221,HP:0000222,HP:0000299,HP:0000368,HP:0000369,HP:0001801,HP:0000278,HP:0000215,HP:0000216,HP:0000218,HP:0011191,HP:0011192,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000325,HP:0000598,HP:0000599,HP:0000597,HP:0000330,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000453,HP:0000454,HP:0000456,HP:0000343,HP:0000344,HP:0000345,HP:0000346,HP:0000220,HP:0000223,HP:0000224,HP:0000219,HP:0000694,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001771,HP:0001821,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'A a female with jacobsen syndrome (omim:147791) who presents with Broad forehead, Face with broad temples and narrow chin, Wide-set eyes, Bushy eyebrows, Arched eyebrows, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, esodeviation, Broad flat nasal bridge, low hanging columella, short philtrum, Thin red part of the upper lip, Abnormal dentition, Apple cheeks, Small ears, Low frontal hairline, Decreased length of neck, small hypothenar eminence, Broad thumb, Dropped arches, Long big toe, Triangular head shape, Flat back of skull, Prominent back of the head, High forehead, Bulging forehead, Decreased width of the forehead, Flat face, Circular face, Broad face, Eye folds, Sparse eyebrow, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, exodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, long philtrum, smooth philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Low set ears, Ears rotated toward back of head, Conductive deafness, Brittle hair, Neck webbing, small thenar eminence, Club feet, Bunion, Short toe, and Toe curvature.': 'HP:0011192,HP:0002094,HP:0000324,HP:0000598,HP:0000597,HP:0000330,HP:0000308,HP:0000508,HP:0000555,HP:0000426,HP:0000456,HP:0000344,HP:0000221,HP:0000685,HP:0000299,HP:0000368,HP:0000270,HP:0000131,HP:0010473,HP:0001190,HP:0001801,HP:0001821,HP:0001826,HP:0000278,HP:0000215,HP:0000216,HP:0000218,HP:0011191,HP:0011193,HP:0000256,HP:0000257,HP:0000255,HP:0000325,HP:0000599,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000556,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000345,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000369,HP:0000371,HP:0001254,HP:0002224,HP:0000133,HP:0010474,HP:0001771,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'Clinical findings such as Prominent back of the head, High forehead, Bulging forehead, Broad forehead, Sparse eyebrow, Arched eyebrows, Downward slanting of the opening between the eyelids, Drooping upper eyelid, exodeviation, Broad flat nasal bridge, low hanging columella, long philtrum, Thin red part of the upper lip, Full upper lip, Full lower lip, Apple cheeks, Small ears, Dropped arches, Long big toe, Triangular head shape, Flat back of skull, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Wide-set eyes, Eye folds, Bushy eyebrows, Increased length of eyelashes, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, short philtrum, smooth philtrum, deep philtrum, Decreased volume of lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Club feet, Bunion, Short toe, Toe curvature, and Abnormality of the reproductive system suggest jacobsen syndrome (omim:147791) in A a female.': 'HP:0000216,HP:0000218,HP:0011191,HP:0011192,HP:0000599,HP:0000597,HP:0000308,HP:0000508,HP:0000556,HP:0000426,HP:0000456,HP:0000343,HP:0000221,HP:0000220,HP:0000222,HP:0000299,HP:0000368,HP:0001801,HP:0001821,HP:0000278,HP:0000215,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000598,HP:0000330,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000344,HP:0000345,HP:0000346,HP:0000223,HP:0000224,HP:0000219,HP:0000694,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001771,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'Clinical findings such as High forehead, Broad forehead, Wide-set eyes, Arched eyebrows, Increased length of eyelashes, Downward slanting of the opening between the eyelids, exodeviation, Bulbous nose, long philtrum, Thin red part of the upper lip, Decreased volume of lower lip, Apple cheeks, small thenar eminence, small hypothenar eminence, Dropped arches, Long big toe, Abnormality of the reproductive system, Triangular head shape, Flat back of skull, Prominent back of the head, Bulging forehead, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Eye folds, Bushy eyebrows, Sparse eyebrow, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Broad flat nasal bridge, Elongated nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, short philtrum, smooth philtrum, deep philtrum, Full upper lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, Broad thumb, Club feet, Bunion, Toe curvature, and umbilical hernia suggest jacobsen syndrome (omim:147791) in A a male.': 'HP:0000218,HP:0011192,HP:0000324,HP:0000597,HP:0000330,HP:0000308,HP:0000556,HP:0000448,HP:0000343,HP:0000221,HP:0000223,HP:0000299,HP:0010474,HP:0010473,HP:0001801,HP:0001821,HP:0000119,HP:0000278,HP:0000215,HP:0000216,HP:0011191,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000325,HP:0000598,HP:0000599,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000426,HP:0000456,HP:0000344,HP:0000345,HP:0000346,HP:0000220,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0001190,HP:0001771,HP:0001825,HP:0001827,HP:0001507',
#  'Clinical findings such as High forehead, Bulging forehead, Broad forehead, Broad face, Wide-set eyes, Sparse eyebrow, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, exodeviation, Broad flat nasal bridge, low hanging columella, long philtrum, smooth philtrum, Thin red part of the upper lip, Apple cheeks, Small ears, Ears rotated toward back of head, Dropped arches, Long big toe, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Eye folds, Bushy eyebrows, Arched eyebrows, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, short philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Low set ears, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Club feet, Bunion, Short toe, Toe curvature, umbilical hernia, and Abnormality of the reproductive system suggest jacobsen syndrome (omim:147791) in A a female.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000255,HP:0000324,HP:0000599,HP:0000330,HP:0000308,HP:0000508,HP:0000556,HP:0000426,HP:0000456,HP:0000343,HP:0000345,HP:0000221,HP:0000299,HP:0000368,HP:0000371,HP:0001801,HP:0001821,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000325,HP:0000598,HP:0000597,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000369,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001771,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'High forehead, bulging forehead, broad forehead, wide-set eyes, downward slanting of the opening between the eyelids, drooping upper eyelid, deep set eye, low hanging columella, short philtrum, thin red part of the upper lip, full lower lip, small ears, brittle hair, small hypothenar eminence, broad thumb, bunion, triangular head shape, flat back of skull, prominent back of the head, decreased width of the forehead, flat face, face with broad temples and narrow chin, circular face, broad face, eye folds, bushy eyebrows, sparse eyebrow, arched eyebrows, increased length of eyelashes, bulging eye, cat eye, clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, broad flat nasal bridge, elongated nose, bulbous nose, nasal tip, upturned, decreased size of nasal tip, long philtrum, smooth philtrum, deep philtrum, full upper lip, decreased volume of lower lip, drooping lower lip, elevated palate, cleft palate, abnormality of dental shape, apple cheeks, low set ears, ears rotated toward back of head, conductive deafness, low frontal hairline, decreased length of neck, neck webbing, small thenar eminence, dropped arches, club feet, long big toe, short toe, toe curvature, umbilical hernia, and abnormality of the reproductive system are observed in A a female with jacobsen syndrome (omim:147791).': 'HP:0000218,HP:0011191,HP:0011192,HP:0000324,HP:0000308,HP:0000508,HP:0000490,HP:0000456,HP:0000344,HP:0000221,HP:0000222,HP:0000368,HP:0002224,HP:0010473,HP:0001190,HP:0001825,HP:0001826,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000325,HP:0000598,HP:0000599,HP:0000597,HP:0000330,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000345,HP:0000346,HP:0000220,HP:0000223,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0000131,HP:0000133,HP:0010474,HP:0001801,HP:0001771,HP:0001827,HP:0001507,HP:0000119',
#  'A a female with jacobsen syndrome (omim:147791) who presents with Triangular head shape, Flat back of skull, High forehead, Broad forehead, Wide-set eyes, Eye folds, Sparse eyebrow, Downward slanting of the opening between the eyelids, Drooping upper eyelid, exodeviation, Broad flat nasal bridge, short philtrum, deep philtrum, Thin red part of the upper lip, small thenar eminence, small hypothenar eminence, umbilical hernia, Prominent back of the head, Bulging forehead, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Bushy eyebrows, Arched eyebrows, Increased length of eyelashes, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, long philtrum, smooth philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, Broad thumb, Dropped arches, Club feet, Long big toe, Bunion, Short toe, Toe curvature, and Abnormality of the reproductive system.': 'HP:0000278,HP:0000215,HP:0000218,HP:0011192,HP:0000324,HP:0000325,HP:0000599,HP:0000308,HP:0000508,HP:0000556,HP:0000426,HP:0000344,HP:0000346,HP:0000221,HP:0010474,HP:0010473,HP:0001507,HP:0000216,HP:0011191,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000598,HP:0000597,HP:0000330,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000343,HP:0000345,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0001190,HP:0001801,HP:0001771,HP:0001825,HP:0001827,HP:0000119',
#  'Clinical findings such as High forehead, Bulging forehead, Broad forehead, Circular face, Wide-set eyes, Eye folds, Sparse eyebrow, Arched eyebrows, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, exodeviation, Broad flat nasal bridge, long philtrum, Ears rotated toward back of head, Decreased length of neck, umbilical hernia, Abnormality of the reproductive system, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Broad face, Bushy eyebrows, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, short philtrum, smooth philtrum, deep philtrum, Thin red part of the upper lip, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Conductive deafness, Low frontal hairline, Brittle hair, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Dropped arches, Club feet, Long big toe, Bunion, Short toe, and Toe curvature suggest jacobsen syndrome (omim:147791) in A a male.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000257,HP:0000324,HP:0000325,HP:0000599,HP:0000597,HP:0000330,HP:0000308,HP:0000508,HP:0000556,HP:0000426,HP:0000343,HP:0000371,HP:0000131,HP:0001507,HP:0000119,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000255,HP:0000598,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000344,HP:0000345,HP:0000346,HP:0000221,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0001254,HP:0000270,HP:0002224,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001801,HP:0001771,HP:0001821,HP:0001825,HP:0001827',
#  'A a male with jacobsen syndrome (omim:147791) who presents with Prominent back of the head, High forehead, Bulging forehead, Broad forehead, Circular face, Broad face, Wide-set eyes, Sparse eyebrow, Arched eyebrows, Increased length of eyelashes, Nasal tip, upturned, short philtrum, Thin red part of the upper lip, Decreased volume of lower lip, Apple cheeks, Low set ears, Ears rotated toward back of head, Long big toe, Triangular head shape, Flat back of skull, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Eye folds, Bushy eyebrows, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Decreased size of nasal tip, low hanging columella, long philtrum, smooth philtrum, deep philtrum, Full upper lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Small ears, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Dropped arches, Club feet, Bunion, Short toe, Toe curvature, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000216,HP:0000218,HP:0011191,HP:0011192,HP:0000257,HP:0000255,HP:0000324,HP:0000599,HP:0000597,HP:0000330,HP:0000453,HP:0000344,HP:0000221,HP:0000223,HP:0000299,HP:0000369,HP:0000371,HP:0001821,HP:0000278,HP:0000215,HP:0011193,HP:0000256,HP:0002094,HP:0000325,HP:0000598,HP:0000308,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000454,HP:0000456,HP:0000343,HP:0000345,HP:0000346,HP:0000220,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000368,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001801,HP:0001771,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'Circular face, bushy eyebrows, downward slanting of the opening between the eyelids, low hanging columella, thin red part of the upper lip, small hypothenar eminence, triangular head shape, flat back of skull, prominent back of the head, high forehead, bulging forehead, broad forehead, decreased width of the forehead, flat face, face with broad temples and narrow chin, broad face, wide-set eyes, eye folds, sparse eyebrow, arched eyebrows, increased length of eyelashes, drooping upper eyelid, deep set eye, bulging eye, cat eye, clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, broad flat nasal bridge, elongated nose, bulbous nose, nasal tip, upturned, decreased size of nasal tip, long philtrum, short philtrum, smooth philtrum, deep philtrum, full upper lip, decreased volume of lower lip, full lower lip, drooping lower lip, elevated palate, cleft palate, abnormality of dental shape, apple cheeks, small ears, low set ears, ears rotated toward back of head, conductive deafness, low frontal hairline, brittle hair, decreased length of neck, neck webbing, small thenar eminence, broad thumb, dropped arches, club feet, long big toe, bunion, toe curvature, umbilical hernia, and abnormality of the reproductive system are observed in A a female with jacobsen syndrome (omim:147791).': 'HP:0000257,HP:0000598,HP:0000308,HP:0000456,HP:0000221,HP:0010473,HP:0000278,HP:0000215,HP:0000216,HP:0000218,HP:0011191,HP:0011192,HP:0011193,HP:0000256,HP:0002094,HP:0000255,HP:0000324,HP:0000325,HP:0000599,HP:0000597,HP:0000330,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000343,HP:0000344,HP:0000345,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0001190,HP:0001801,HP:0001771,HP:0001821,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
#  'A a female shows clinical features including High forehead, Bulging forehead, Broad forehead, Wide-set eyes, Eye folds, Sparse eyebrow, Arched eyebrows, Downward slanting of the opening between the eyelids, Broad flat nasal bridge, low hanging columella, Bunion, Toe curvature, umbilical hernia, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Bushy eyebrows, Increased length of eyelashes, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, long philtrum, short philtrum, smooth philtrum, deep philtrum, Thin red part of the upper lip, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Dropped arches, Club feet, Long big toe, Short toe, and Abnormality of the reproductive system, consistent with a diagnosis of jacobsen syndrome (omim:147791).': 'HP:0000218,HP:0011191,HP:0011192,HP:0000324,HP:0000325,HP:0000599,HP:0000597,HP:0000308,HP:0000426,HP:0000456,HP:0001825,HP:0001826,HP:0001507,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000598,HP:0000330,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000343,HP:0000344,HP:0000345,HP:0000346,HP:0000221,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001801,HP:0001771,HP:0001821,HP:0001827,HP:0000119',
#  'This case involves A a male diagnosed with jacobsen syndrome (omim:147791), exhibiting High forehead, Broad forehead, Sparse eyebrow, Arched eyebrows, low hanging columella, long philtrum, smooth philtrum, Abnormal dentition, Neck webbing, small hypothenar eminence, Broad thumb, Dropped arches, Abnormality of the reproductive system, Triangular head shape, Flat back of skull, Prominent back of the head, Bulging forehead, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Circular face, Broad face, Wide-set eyes, Eye folds, Bushy eyebrows, Increased length of eyelashes, Downward slanting of the opening between the eyelids, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, esodeviation, exodeviation, Broad flat nasal bridge, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, short philtrum, deep philtrum, Thin red part of the upper lip, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Apple cheeks, Small ears, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, small thenar eminence, Club feet, Long big toe, Bunion, Toe curvature, and umbilical hernia.': 'HP:0000218,HP:0011192,HP:0000599,HP:0000597,HP:0000456,HP:0000343,HP:0000345,HP:0000685,HP:0000133,HP:0010473,HP:0001190,HP:0001801,HP:0000119,HP:0000278,HP:0000215,HP:0000216,HP:0011191,HP:0011193,HP:0000256,HP:0002094,HP:0000257,HP:0000255,HP:0000324,HP:0000325,HP:0000598,HP:0000330,HP:0000308,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000344,HP:0000346,HP:0000221,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0010474,HP:0001771,HP:0001821,HP:0001825,HP:0001827,HP:0001507',
#  'A a male with jacobsen syndrome (omim:147791) who presents with High forehead, Bulging forehead, Broad forehead, Circular face, Wide-set eyes, Sparse eyebrow, Downward slanting of the opening between the eyelids, esodeviation, Broad flat nasal bridge, long philtrum, smooth philtrum, Thin red part of the upper lip, Apple cheeks, Small ears, Long big toe, Triangular head shape, Flat back of skull, Prominent back of the head, Decreased width of the forehead, Flat face, Face with broad temples and narrow chin, Broad face, Eye folds, Bushy eyebrows, Arched eyebrows, Increased length of eyelashes, Drooping upper eyelid, Deep set eye, Bulging eye, Cat eye, Clouding of the lens of the eye, ectopia lentis, exodeviation, Elongated nose, Bulbous nose, Nasal tip, upturned, Decreased size of nasal tip, low hanging columella, short philtrum, deep philtrum, Full upper lip, Decreased volume of lower lip, Full lower lip, Drooping lower lip, Elevated palate, Cleft palate, Abnormality of dental shape, Low set ears, Ears rotated toward back of head, Conductive deafness, Low frontal hairline, Brittle hair, Decreased length of neck, Neck webbing, small thenar eminence, small hypothenar eminence, Broad thumb, Dropped arches, Club feet, Bunion, Short toe, Toe curvature, umbilical hernia, and Abnormality of the reproductive system.': 'HP:0000218,HP:0011191,HP:0011192,HP:0000257,HP:0000324,HP:0000599,HP:0000308,HP:0000555,HP:0000426,HP:0000343,HP:0000345,HP:0000221,HP:0000299,HP:0000368,HP:0001821,HP:0000278,HP:0000215,HP:0000216,HP:0011193,HP:0000256,HP:0002094,HP:0000255,HP:0000325,HP:0000598,HP:0000597,HP:0000330,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000556,HP:0000431,HP:0000448,HP:0000453,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000219,HP:0000694,HP:0000369,HP:0000371,HP:0001254,HP:0000270,HP:0002224,HP:0000131,HP:0000133,HP:0010474,HP:0010473,HP:0001190,HP:0001801,HP:0001771,HP:0001825,HP:0001827,HP:0001507,HP:0000119',
# ...
#  'A a female with hypomagnesemia 3, renal (omim:248250) who presents with Elevated urine calcium levels, hypermagnesiuria, elevated circulating parathyroid hormone level, Increased calcium level in kidney, renal magnesium wasting, Frequent urinary tract infections, Increased urine output, Extreme thirst, Abdominal discomfort, Throwing up, Faltering weight, Renal failure, endstage, Kidney stones, High urine uric acid level, sterile pyuria, Small amount of blood in urine, Weak and soft bones, and Intermittent involuntary muscle spasm.': 'HP:0003214,HP:0002130,HP:0002086,HP:0000084,HP:0002140,HP:0000082,HP:0000085,HP:0001871,HP:0000078,HP:0000087,HP:0000088,HP:00000755,HP:0000086,HP:0004470,HP:0001319,HP:0002041',
#  'A a male shows clinical features including Elevated urine calcium levels, hypermagnesiuria, elevated circulating parathyroid hormone level, Increased calcium level in kidney, Renal failure, renal magnesium wasting, Abdominal discomfort, Renal failure, endstage, Kidney stones, High urine uric acid level, sterile pyuria, Small amount of blood in urine, Frequent urinary tract infections, Increased urine output, Extreme thirst, Weak and soft bones, Intermittent involuntary muscle spasm, Throwing up, and Faltering weight, consistent with a diagnosis of hypomagnesemia 3, renal (omim:248250).': 'HP:0003214,HP:0002086,HP:0000084,HP:0002140,HP:0002130,HP:0000082,HP:0000085,HP:0001871,HP:0000078,HP:0000087,HP:0000088,HP:0000755,HP:0000086,HP:0004470,HP:0001319,HP:0002041',
#  'A a male shows clinical features including Elevated urine calcium levels, hypermagnesiuria, elevated circulating parathyroid hormone level, Increased calcium level in kidney, Renal failure, renal magnesium wasting, Renal failure, endstage, Kidney stones, High urine uric acid level, sterile pyuria, Small amount of blood in urine, Frequent urinary tract infections, Increased urine output, Extreme thirst, Weak and soft bones, Intermittent involuntary muscle spasm, Abdominal discomfort, Throwing up, and Faltering weight, consistent with a diagnosis of hypomagnesemia 3, renal (omim:248250).': 'HP:0003214,HP:0002086,HP:0000084,HP:0002140,HP:0000082,HP:0000085,HP:0001871,HP:0000078,HP:0000087,HP:0000088,HP:0000755,HP:0000086,HP:0004470,HP:0001319,HP:0002041',
#  'Clinical findings such as Elevated urine calcium levels, hypermagnesiuria, elevated circulating parathyroid hormone level, Increased calcium level in kidney, Renal failure, Kidney stones, renal magnesium wasting, sterile pyuria, Small amount of blood in urine, Frequent urinary tract infections, Increased urine output, Extreme thirst, Weak and soft bones, Intermittent involuntary muscle spasm, Abdominal discomfort, Throwing up, Faltering weight, Renal failure, endstage, and High urine uric acid level suggest hypomagnesemia 3, renal (omim:248250) in A a female.': 'HP:0003214,HP:0002086,HP:0000084,HP:0000082,HP:0000085,HP:0000078,HP:0002140,HP:0000088,HP:0000755,HP:0000086,HP:0004470,HP:0001319,HP:0002041,HP:0001871,HP:0000087',
#  'A a male shows clinical features including Elevated urine calcium levels, hypermagnesiuria, elevated circulating parathyroid hormone level, Increased calcium level in kidney, Kidney stones, renal magnesium wasting, sterile pyuria, Frequent urinary tract infections, Increased urine output, Extreme thirst, Abdominal discomfort, Throwing up, Renal failure, endstage, hypocitraturia, High urine uric acid level, Small amount of blood in urine, Weak and soft bones, Intermittent involuntary muscle spasm, and Faltering weight, consistent with a diagnosis of hypomagnesemia 3, renal (omim:248250).': 'HP:0003214,HP:0002086,HP:0000084,HP:0000082,HP:0000085,HP:0000078,HP:0002140,HP:0000088,HP:0000755,HP:0000086,HP:0004470,HP:0001319,HP:0002041,HP:0001871,HP:0000087',
#  'Increased calcium level in kidney, elevated urine calcium levels, bloody urine, low blood magnesium levels, amelogenesis imperfecta, renal failure, thin dental enamel, renal failure, endstage, and hypomature enamel are observed in A a male with hypomagnesemia 3, renal (omim:248250).': 'HP:0000084,HP:0000078,HP:0002130,HP:0000694,HP:0000308,HP:0000324,HP:0000453,HP:0000448,HP:0000431,HP:0000376,HP:0000369,HP:0001249,HP:0001263,HP:0000598,HP:0000343,HP:0001191,HP:0004301,HP:0005977,HP:0001344,HP:0002361,HP:0001252,HP:0000717,HP:0007018,HP:0000340,HP:0000341,HP:0000219,HP:0000486,HP:0000332,HP:0000365,HP:0002719,HP:0002071,HP:0001552,HP:0001507,HP:0000270',
#  'Increased calcium level in kidney, amelogenesis imperfecta, renal failure, endstage, elevated urine calcium levels, low blood magnesium levels, hypomature enamel, and thin dental enamel are observed in A a female with hypomagnesemia 3, renal (omim:248250).': 'HP:0000084,HP:0000078,HP:0002130,HP:0000694,HP:0003214',
#  'Clinical findings such as Knock knees, Muscle weakness, Decreased body height, Increased calcium level in kidney, Renal failure, Elevated urine calcium levels, hypermagnesiuria, renal magnesium wasting, Elevated creatinine, Close sighted, increased circulating beta-c-terminal telopeptide concentration, Low blood magnesium levels, High blood phosphate levels, Low blood calcium levels, elevated circulating parathyroid hormone level, Elevated alkaline phosphatase, Renal failure, endstage, Bloody urine, Abnormal curving of the cornea or lens of the eye, Involuntary, rapid, rhythmic eye movements, Cross-eyed, and Farsightedness suggest hypomagnesemia 3, renal (omim:248250) in A a male.': 'HP:0000711,HP:0001252,HP:0004301,HP:0000084,HP:0000078,HP:0003214,HP:0000082,HP:0000085,HP:0000079,HP:0000087,HP:0002130,HP:0000506,HP:0000515,HP:0000618,HP:0000486,HP:0000507,HP:0000970,HP:0000077,HP:0002140,HP:0000088,HP:0000755,HP:0000086,HP:0004470,HP:0001319,HP:0002041,HP:0001871,HP:0002086,HP:0003198',
#  'A a female shows clinical features including Bloody urine, Increased calcium level in kidney, Renal failure, Elevated urine calcium levels, hypermagnesiuria, renal magnesium wasting, Increased urine output, Extreme thirst, Elevated creatinine, increased circulating beta-c-terminal telopeptide concentration, Low blood magnesium levels, elevated circulating parathyroid hormone level, Renal failure, endstage, Abnormal curving of the cornea or lens of the eye, Involuntary, rapid, rhythmic eye movements, Cross-eyed, Farsightedness, Close sighted, High blood phosphate levels, Low blood calcium levels, and Elevated alkaline phosphatase, consistent with a diagnosis of hypomagnesemia 3, renal (omim:248250).': 'HP:0000755,HP:0000084,HP:0000078,HP:0000082,HP:0000085,HP:0000079,HP:0000087,HP:0002130,HP:0002140,HP:0000088,HP:0000086,HP:0004470,HP:0001319,HP:0002041,HP:0001871,HP:0002086,HP:0003198,HP:0003214,HP:0000515,HP:0000618,HP:0000486,HP:0000507,HP:0000506',
#  'Intellectual disability, delayed motor skills, aggression, eeg abnormality, seizure affecting one half of brain, focal cortical dysplasia, rapid breathing, coarse facial appearance, big lower jaw, wide-spaced teeth, low frontal hairline, monobrow, fleshy earlobe, elevated palate, decreased size of tooth, prominent tongue, low hanging columella, increased length of eyelashes, thin red part of the upper lip, broad forehead, eye folds, large ears, smooth philtrum, short philtrum, bulbous nose, broad mouth, short columella, upward slanting of the opening between the eyelids, bulging forehead, tented mouth, sparse eyebrow, decreased length of nose, frontal bossing, wide-set eyes, and decreased width of the forehead are observed in A patient with pitt-hopkins like syndrome 1 (omim:610042).': 'HP:0001249,HP:0001271,HP:0000716,HP:0002367,HP:0002107,HP:0002096,HP:0000268,HP:0000341,HP:0000672,HP:0000270,HP:0000332,HP:0000308,HP:0000448,HP:0000343,HP:0000345,HP:0009774,HP:0000376,HP:0000597,HP:0000324,HP:0000325,HP:0000453,HP:0000221,HP:0000340,HP:0000231,HP:0000219,HP:0000257,HP:0000321,HP:0000369,HP:0001263,HP:0001252,HP:0000717,HP:0007018,HP:0000330,HP:0000508,HP:0000490,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000220,HP:0000223,HP:0000222,HP:0000224,HP:0000694,HP:0000299,HP:0001254,HP:0001317,HP:0001255,HP:0000724',
#  'Epilepsy, schizophrenia, global developmental delay, intellectual disability, and deficiency of speech development are observed in A a female with pitt-hopkins like syndrome 1 (omim:610042).': 'HP:0001250,HP:0000717,HP:0001263,HP:0001344,HP:0001249,HP:0000716,HP:0000721,HP:0000718,HP:0001257,HP:0000268,HP:0000507,HP:0005280,HP:0000444,HP:0000224,HP:0000221,HP:0000028,HP:0002077,HP:0000308,HP:0001255,HP:0002074,HP:0002472,HP:0001320,HP:0002365,HP:0002066,HP:0001386,HP:0002363,HP:0000506,HP:0001843,HP:0009771,HP:0000505,HP:0001831,HP:0000047,HP:0000822,HP:0000860,HP:0001771,HP:0000618,HP:0000486,HP:0000344,HP:0000367,HP:0000025,HP:0001197,HP:0000078,HP:0001370,HP:0000266,HP:0001287,HP:0002079,HP:0002070,HP:0002120,HP:0002360,HP:0001718,HP:0005479',
#  'This case involves A a female diagnosed with pitt-hopkins like syndrome 1 (omim:610042), exhibiting global developmental delay, Intellectual disability, Deficiency of speech development, Autism spectrum disorder, eeg abnormality, Epilepsy, periventricular leukomalacia, Abnormally small head, Deafness, Coarse facial appearance, Big lower jaw, Wide-spaced teeth, Low frontal hairline, Monobrow, Fleshy earlobe, Elevated palate, Decreased size of tooth, Prominent tongue, low hanging columella, Increased length of eyelashes, Thin red part of the upper lip, Broad forehead, Eye folds, Large ears, smooth philtrum, short philtrum, Bulbous nose, Broad mouth, short columella, Upward slanting of the opening between the eyelids, Bulging forehead, Tented mouth, Sparse eyebrow, Decreased length of nose, and Decreased width of the forehead.': 'HP:0001263,HP:0000671,HP:0000343,HP:0001191,HP:0004301,HP:0005977,HP:0001344,HP:0002361,HP:0001252,HP:0001249,HP:0000717,HP:0007018,HP:0000268,HP:0000507,HP:0005280,HP:0000444,HP:0000431,HP:0000376,HP:0000369,HP:0000340,HP:0000341,HP:0000219,HP:0000257,HP:0000308,HP:0001255,HP:0002074,HP:0002472,HP:0001320,HP:0002365,HP:0002066,HP:0001386,HP:0002363,HP:0000506,HP:0001843,HP:0009771,HP:0000505,HP:0001831,HP:0000047,HP:0000822,HP:0000860,HP:0001771,HP:0000618,HP:0000486,HP:0000344,HP:0000367,HP:0000025,HP:0001197,HP:0000078,HP:0001370,HP:0000266,HP:0001287,HP:0002079,HP:0002070,HP:0002120,HP:0002360,HP:0001718,HP:0005479',
#  'Clinical findings such as global developmental delay, Intellectual disability, Deficiency of speech development, Abnormally small head, Rapid breathing, Small cerebellum, Full lips, Broad mouth, Autism spectrum disorder, Repetitive movements, focal cortical dysplasia, periventricular leukomalacia, thick corpus callosum, intraventricular hemorrhage, reduced cerebral white matter volume, thin corpus callosum, Coarse facial appearance, Big lower jaw, Wide-spaced teeth, Low frontal hairline, Monobrow, Fleshy earlobe, Elevated palate, Decreased size of tooth, Prominent tongue, low hanging columella, Increased length of eyelashes, Thin red part of the upper lip, Broad forehead, Eye folds, Large ears, smooth philtrum, short philtrum, Bulbous nose, short columella, Upward slanting of the opening between the eyelids, Bulging forehead, Tented mouth, Sparse eyebrow, Decreased length of nose, frontal bossing, Wide-set eyes, Decreased width of the forehead, and Constipation suggest pitt-hopkins like syndrome 1 (omim:610042) in A a female.': 'HP:0001263,HP:0000671,HP:0000343,HP:0001191,HP:0004301,HP:0005977,HP:0001344,HP:0002361,HP:0001252,HP:0001249,HP:0000717,HP:0007018,HP:0000268,HP:0000507,HP:0005280,HP:0000444,HP:0000431,HP:0000376,HP:0000369,HP:0000340,HP:0000341,HP:0000219,HP:0000257,HP:0000308,HP:0001255,HP:0002074,HP:0002472,HP:0001320,HP:0002365,HP:0002066,HP:0001386,HP:0002363,HP:0000506,HP:0001843,HP:0009771,HP:0000505,HP:0001831,HP:0000047,HP:0000822,HP:0000860,HP:0001771,HP:0000618,HP:0000486,HP:0000344,HP:0000367,HP:0000025,HP:0001197,HP:0000078,HP:0001370,HP:0000266,HP:0001287,HP:0002079,HP:0002070,HP:0002120,HP:0002360,HP:0001718,HP:0005479',
#  'A a male with pitt-hopkins like syndrome 1 (omim:610042) who presents with global developmental delay, Intellectual disability, Deficiency of speech development, Rapid breathing, Full lips, Broad mouth, Abnormally small head, Autism spectrum disorder, Repetitive movements, focal cortical dysplasia, periventricular leukomalacia, thick corpus callosum, intraventricular hemorrhage, reduced cerebral white matter volume, thin corpus callosum, Small cerebellum, Coarse facial appearance, Big lower jaw, Wide-spaced teeth, Low frontal hairline, Monobrow, Fleshy earlobe, Elevated palate, Decreased size of tooth, Prominent tongue, low hanging columella, Increased length of eyelashes, Thin red part of the upper lip, Broad forehead, Eye folds, Large ears, smooth philtrum, short philtrum, Bulbous nose, short columella, Upward slanting of the opening between the eyelids, Bulging forehead, Tented mouth, Sparse eyebrow, Decreased length of nose, frontal bossing, Wide-set eyes, Decreased width of the forehead, and Constipation.': 'HP:0001263,HP:0000671,HP:0000343,HP:0001191,HP:0004301,HP:0005977,HP:0001344,HP:0002361,HP:0001252,HP:0001249,HP:0000717,HP:0007018,HP:0000268,HP:0000507,HP:0005280,HP:0000444,HP:0000431,HP:0000376,HP:0000369,HP:0000340,HP:0000341,HP:0000219,HP:0000257,HP:0000308,HP:0001255,HP:0002074,HP:0002472,HP:0001320,HP:0002365,HP:0002066,HP:0001386,HP:0002363,HP:0000506,HP:0001843,HP:0009771,HP:0000505,HP:0001831,HP:0000047,HP:0000822,HP:0000860,HP:0001771,HP:0000618,HP:0000486,HP:0000344,HP:0000367,HP:0000025,HP:0001197,HP:0000078,HP:0001370,HP:0000266,HP:0001287,HP:0002079,HP:0002070,HP:0002120,HP:0002360,HP:0001718,HP:0005479',
#  'A a female with pitt-hopkins like syndrome 1 (omim:610042) who presents with global developmental delay, Intellectual disability, Deficiency of speech development, Autism spectrum disorder, Repetitive movements, Rapid breathing, Abnormally small head, Coarse facial appearance, Big lower jaw, Wide-spaced teeth, Low frontal hairline, Monobrow, Fleshy earlobe, Elevated palate, Decreased size of tooth, Prominent tongue, low hanging columella, Increased length of eyelashes, Thin red part of the upper lip, Full lips, Broad forehead, Eye folds, Large ears, smooth philtrum, short philtrum, Bulbous nose, Broad mouth, short columella, Upward slanting of the opening between the eyelids, Bulging forehead, Tented mouth, Sparse eyebrow, Decreased length of nose, frontal bossing, Wide-set eyes, Decreased width of the forehead, and Constipation.': 'HP:0001263,HP:0000671,HP:0001344,HP:0000209,HP:0000220,HP:0000345,HP:0000343,HP:0000252,HP:0000341,HP:0000321,HP:0000717,HP:0000716,HP:0000721,HP:0000718,HP:0001249,HP:0001252,HP:0002321,HP:0000308,HP:0000324,HP:0000598,HP:0000599,HP:0000597,HP:0000330,HP:0000508,HP:0000539,HP:0000455,HP:0000515,HP:0000512,HP:0000555,HP:0000556,HP:0000426,HP:0000431,HP:0000454,HP:0000456,HP:0000344,HP:0000346,HP:0000221,HP:0000219,HP:0000694,HP:0000299,HP:0000368,HP:0000369,HP:0000371,HP:0001254,HP:0001317,HP:0001255,HP:0000738,HP:0002304,HP:0002066,HP:0001386,HP:0002363,HP:0000507,HP:0000506,HP:0001843,HP:0009771,HP:0000505,HP:0001831,HP:0000047,HP:0000822,HP:0000860,HP:0001771,HP:0000618,HP:0000260,HP:0000486,HP:0000367,HP:0000025,HP:0001197,HP:0000078,HP:0001370,HP:0000266,HP:0000327,HP:0001287,HP:0002079,HP:0002070,HP:0002120,HP:0002360,HP:0001718,HP:0005479'}

# %%
discache

# %%
# output_str = gemini_phenotype_extractor(clinical_summary)

# %%
df_hpo_mapping = pd.read_csv('./reference/2025-08-01_orphanet_WGS_database(HPO_ID_Mapping_v20250506).csv', sep=',')
hpo_mapping_dict = {}
for idx in df_hpo_mapping.index:
    hpo_mapping_dict[df_hpo_mapping.input_hpo_id[idx]] = df_hpo_mapping.mapped_main_id[idx]

# %%
def hpo_map(hpo_id_list_str):
    if hpo_id_list_str =='-':
        return '-'
    hpo_id_list = hpo_id_list_str.split(',')
    normalized_hpo_id_list = []
    for hpo_id in hpo_id_list:
        if hpo_id not in normalized_hpo_id_list:
            normalized_hpo_id_list.append(hpo_mapping_dict.get(hpo_id,'-'))
    return ','.join(normalized_hpo_id_list)

def accuracy_calculator(true_hpo_str, pred_hpo_str):
    true_hpo_list = true_hpo_str.split(',')
    pred_hpo_list = pred_hpo_str.split(',')
    mapped_hpo_list = [hpo for hpo in pred_hpo_list if hpo in true_hpo_list]
    return len(mapped_hpo_list)/len(true_hpo_list)

# %% [markdown]
# ## Gemini Flash Lite 2.5 Usage and Price

# %%
import pandas as pd
phenopacket = pd.read_excel('./reference/20250805_phenopacket_with_demographics_summary_phenobert_result.xlsx')

# %%
phenopacket.head(2)
# Out:
#              case_id     sex  age                        diagnoses  \
# 0  PMID_15266616_100  FEMALE  NaN  Jacobsen syndrome (OMIM:147791)
# 1  PMID_15266616_101  FEMALE  NaN  Jacobsen syndrome (OMIM:147791)
#
#                                            hpo_terms  \
# 0  High forehead (HP:0000348); Prominent forehead...
# 1  High forehead (HP:0000348); Prominent forehead...
#
#                                     clinical_summary  \
# 0  A a female shows clinical features including H...
# 1  This case involves A a female diagnosed with j...
#
#                                              hpo_ids  \
# 0  HP:0000348,HP:0011220,HP:0000337,HP:0002553,HP...
# 1  HP:0000348,HP:0011220,HP:0000337,HP:0000311,HP...
#
#                                   normalized_hpo_ids  \
# 0  HP:0000348,HP:0011220,HP:0000337,HP:0002553,HP...
# 1  HP:0000348,HP:0011220,HP:0000337,HP:0000311,HP...
#
#                                    phenobert_hpo_ids  \
# 0  HP:0006482,HP:0000078,HP:0000293,HP:0002553,HP...
# 1  HP:0006482,HP:0000078,HP:0000293,HP:0002553,HP...
#
#                         normalized_phenobert_hpo_ids  phenobert_accuracy
# 0  HP:0006482,HP:0000078,HP:0000293,HP:0002553,HP...            0.952381
# 1  HP:0006482,HP:0000078,HP:0000293,HP:0002553,HP...            0.937500

# %%
clinical_summary_list = phenopacket['clinical_summary'].to_list()
hpo_terms_list = phenopacket['hpo_terms'].to_list()
prompt_1 = f"""Given a paragraph of patient information from discharge note, please extract the phenotype about this patient only.

Check the Human Phenotype Ontology (HPO) database to determine the phenotype.

Only output the extracted phenotypes.

Use the format: {{‘HPO’: ‘HP:0000000’, ‘Phenotype’: ‘Phenotype description’}}

Patient information:"""

# %%
price_info = gemini_price_counter(
    prompt=prompt_1,
    input_list=clinical_summary_list,
    output_list=hpo_terms_list,
)

print(f"總輸入 token 數: {price_info['total_input_tokens']}")
print(f"總輸出 token 數: {price_info['total_output_tokens']}")
print(f"總費用 (USD): {price_info['total_cost_usd']:.8f}")
# Out:
# 總輸入 token 數: 1066473
# 總輸出 token 數: 2465233
# 總費用 (USD): 1.09274050

# %%
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
gemini_FL_hpo_list =  process_summaries_in_parallel(phenopacket['clinical_summary'].to_list(), max_workers=1)
# Out:
# 執行緒 123630722733760: 正在初始化新的 session...
# 處理臨床摘要中:   0%|          | 0/8174 [00:00<?, ?it/s]
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'Recurrent fungal infections, d...'
# 快取命中！跳過處理：'Chronic mucocutaneous candidia...'
# 快取命中！跳過處理：'Chronic mucocutaneous candidia...'
# 快取命中！跳過處理：'Megaloblastic anemia, high uri...'
# 快取命中！跳過處理：'Clinical findings such as Inte...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'Intellectual disability, incre...'
# 快取命中！跳過處理：'Clinical findings such as Inte...'
# 快取命中！跳過處理：'Abnormality of balance, loss o...'
# 快取命中！跳過處理：'Clinical findings such as Brui...'
# 快取命中！跳過處理：'Clinical findings such as lowe...'
# 快取命中！跳過處理：'Patchy darkened skin, decrease...'
# 快取命中！跳過處理：'Patchy darkened skin, decrease...'
# 快取命中！跳過處理：'A a male with intellectual dev...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'Clinical findings such as Shor...'
# 快取命中！跳過處理：'Short feet, circular face, inc...'
# 快取命中！跳過處理：'Clinical findings such as Shor...'
# 快取命中！跳過處理：'Short feet, circular face, inc...'
# 快取命中！跳過處理：'A a female with ectopia lentis...'
# 快取命中！跳過處理：'A a female with ectopia lentis...'
# 快取命中！跳過處理：'A a male with ectopia lentis, ...'
# 快取命中！跳過處理：'Clinical findings such as ecto...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Ectopia lentis, close sighted,...'
# 快取命中！跳過處理：'Clinical findings such as park...'
# 快取命中！跳過處理：'Babinski sign, scissor gait, c...'
# 快取命中！跳過處理：'Babinski sign, scissor gait, c...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Sensorineural hearing impairme...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Sensorineural hearing impairme...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'Webbed fingers or toes, preaxi...'
# 快取命中！跳過處理：'Clinical findings such as post...'
# 快取命中！跳過處理：'A patient with greig cephalopo...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'Having too much body fat, shor...'
# 快取命中！跳過處理：'Clinical findings such as Shor...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'A patient with hmg-coa synthas...'
# 快取命中！跳過處理：'A patient with hmg-coa synthas...'
# 快取命中！跳過處理：'A patient with hmg-coa synthas...'
# 快取命中！跳過處理：'A patient with hmg-coa synthas...'
# 快取命中！跳過處理：'A patient with hmg-coa synthas...'
# 快取命中！跳過處理：'A a female with neurodevelopme...'
# 快取命中！跳過處理：'Clinical findings such as opti...'
# 快取命中！跳過處理：'Clinical findings such as opti...'
# 快取命中！跳過處理：'Clinical findings such as elev...'
# 快取命中！跳過處理：'Clinical findings such as atax...'
# 快取命中！跳過處理：'Clinical findings such as atax...'
# 快取命中！跳過處理：'Clinical findings such as atax...'
# 快取命中！跳過處理：'Clinical findings such as atax...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Grand mal seizures, seizure af...'
# 快取命中！跳過處理：'Grand mal seizures, seizure af...'
# 快取命中！跳過處理：'Clinical findings such as Quiv...'
# 快取命中！跳過處理：'Clinical findings such as Quiv...'
# 快取命中！跳過處理：'First degree atrioventricular ...'
# 快取命中！跳過處理：'Clinical findings such as Noni...'
# 快取命中！跳過處理：'A a female with lipodystrophy,...'
# 快取命中！跳過處理：'A a female with lipodystrophy,...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Renal failure, endstage, enlar...'
# 快取命中！跳過處理：'Freckling, plexiform neurofibr...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'Clinical findings such as Frec...'
# 快取命中！跳過處理：'A a female with neurofibromato...'
# 快取命中！跳過處理：'A a female with neurofibromato...'
# 快取命中！跳過處理：'Clinical findings such as Frec...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'Clinical findings such as Frec...'
# 快取命中！跳過處理：'Clinical findings such as neur...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient with neurofibromatos...'
# 快取命中！跳過處理：'A patient with neurofibromatos...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Clinical findings such as plex...'
# 快取命中！跳過處理：'Clinical findings such as plex...'
# 快取命中！跳過處理：'Clinical findings such as plex...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as axil...'
# 快取命中！跳過處理：'Freckling, multiple birthmarks...'
# 快取命中！跳過處理：'A a male with neurofibromatosi...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Freckling, multiple birthmarks...'
# 快取命中！跳過處理：'A a male with neurofibromatosi...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Clinical findings such as Frec...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'A a male with neurofibromatosi...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a female with neurofibromato...'
# 快取命中！跳過處理：'Dementia, grand mal seizures, ...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as Gran...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Clinical findings such as Clou...'
# 快取命中！跳過處理：'Clinical findings such as mult...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as mult...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as mult...'
# 快取命中！跳過處理：'Clinical findings such as mult...'
# 快取命中！跳過處理：'A patient with prolonged elect...'
# 快取命中！跳過處理：'A patient with cone-rod dystro...'
# 快取命中！跳過處理：'A patient with cone-rod dystro...'
# 快取命中！跳過處理：'A a female with leber congenit...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'Clinical findings such as Invo...'
# 快取命中！跳過處理：'Involuntary, rapid, rhythmic e...'
# 快取命中！跳過處理：'Fluid-filled cyst in spinal co...'
# 快取命中！跳過處理：'Clinical findings such as Abno...'
# 快取命中！跳過處理：'Clinical findings such as Perm...'
# 快取命中！跳過處理：'Clinical findings such as epil...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'Seizure affecting one half of ...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Clinical findings such as epil...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'Clinical findings such as Auti...'
# 快取命中！跳過處理：'Clinical findings such as Auti...'
# 快取命中！跳過處理：'Autism and epilepsy are observ...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as Epil...'
# 快取命中！跳過處理：'Clinical findings such as Epil...'
# 快取命中！跳過處理：'Clinical findings such as Epil...'
# 快取命中！跳過處理：'Clinical findings such as Seiz...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'Epileptic encephalopathy and e...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient with developmental a...'
# 快取命中！跳過處理：'Epileptic encephalopathy and e...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as Epil...'
# 快取命中！跳過處理：'Epileptic encephalopathy and e...'
# 快取命中！跳過處理：'Clinical findings such as Auti...'
# 快取命中！跳過處理：'A patient with myopia 6 (omim:...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Febrile seizure, bilateral ton...'
# 快取命中！跳過處理：'Febrile seizure, bilateral ton...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female with distal renal t...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Asymmetry of the posterior hea...'
# 快取命中！跳過處理：'A a male with coffin-siris syn...'
# 快取命中！跳過處理：'Clinical findings such as Male...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a male with deafness, autoso...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'A a male shows clinical featur...'
# 快取命中！跳過處理：'Clinical findings such as infa...'
# 快取命中！跳過處理：'A patient with sulfite oxidase...'
# 快取命中！跳過處理：'A patient with sulfite oxidase...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient with sulfite oxidase...'
# 快取命中！跳過處理：'A patient with sulfite oxidase...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Secundum atrial septal defect,...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'Clinical findings such as self...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Clinical findings such as self...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'A patient with multiple self-h...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Clinical findings such as self...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'Self-healing squamous epitheli...'
# 快取命中！跳過處理：'Clinical findings such as self...'
# 快取命中！跳過處理：'A patient with tubulointerstit...'
# 快取命中！跳過處理：'Stage 1 chronic kidney disease...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'A patient shows clinical featu...'
# 快取命中！跳過處理：'This case involves A patient d...'
# 快取命中！跳過處理：'Clinical findings such as Chro...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'A a male with tubulointerstiti...'
# 快取命中！跳過處理：'A a male with tubulointerstiti...'
# 快取命中！跳過處理：'This case involves A a male di...'
# 快取命中！跳過處理：'Clinical findings such as Rena...'
# 快取命中！跳過處理：'A a female shows clinical feat...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'This case involves A a female ...'
# 快取命中！跳過處理：'A a female with tubulointersti...'
# 快取命中！跳過處理：'Clinical findings such as Rena...'
# 快取命中！跳過處理：'A a female with tubulointersti...'
# 快取命中！跳過處理：'A a male with intellectual dev...'

# %%
gemini_FL_hpo_list
# Out:
# ['HP:0000218,HP:0011194,HP:0000598,HP:0010770,HP:0001892,HP:0000119,HP:0000278,HP:0005488,HP:0000256,HP:0002095,HP:0000324,HP:0000597,HP:0000322,HP:0000508,HP:0000490,HP:0000426,HP:0000343,HP:0000219,HP:0000175,HP:0000368,HP:0000405,HP:0002224',
#  'HP:0000218,HP:0011191,HP:0000241,HP:0000634,HP:0000598,HP:0000636,HP:0000582,HP:0000508,HP:0000457,HP:0000173,HP:0000343,HP:0000220,HP:0000298,HP:0010773,HP:0001884,HP:0000230,HP:0000490,HP:0000505,HP:0000485,HP:0000507,HP:0000426,HP:0000219,HP:0000175,HP:0000368,HP:0001314,HP:0002224,HP:0000132,HP:0000955,HP:0000150',
#  'HP:0000211,HP:0000213,HP:0000336,HP:0000587,HP:0000508,HP:0000343,HP:0000369,HP:0000370,HP:0011744,HP:0011745,HP:0001882,HP:0001874,HP:0001877,HP:0001875,HP:0005498,HP:0000244,HP:0000236,HP:0011220,HP:0000241,HP:0000586,HP:0000577,HP:0000578,HP:0000598,HP:0000490,HP:0000539,HP:0000505,HP:0000477,HP:0000511,HP:0000512,HP:0000513,HP:0000426,HP:0000431,HP:0000433,HP:0000434,HP:0000440,HP:0000219,HP:0000220,HP:0000218,HP:0000175,HP:0000290,HP:0000405,HP:0000277,HP:0001077,HP:0000280,HP:0001197,HP:0001771,HP:0001876,HP:0001512,HP:0000007']

# %%
phenopacket['gemini_flash_lite_25_hpo_ids'] = gemini_FL_hpo_list

# %%
phenopacket['gemini_flash_lite_25_hpo_idss'] = phenopacket['gemini_flash_lite_25_hpo_ids'].fillna('-')

# %%
phenopacket['normalized_gemini_flash_lite_25_hpo_ids'] = phenopacket['gemini_flash_lite_25_hpo_ids'].apply(hpo_map)

# %%
phenopacket['gemini_flash_lite_25_accuracy'] = phenopacket.apply(lambda x:accuracy_calculator(x.normalized_hpo_ids, x.normalized_gemini_flash_lite_25_hpo_ids), axis=1)

# %%
phenopacket['gemini_flash_lite_25_accuracy'].mean()
# Out:
# np.float64(0.005516715510062375)

# %%
phenopacket[phenopacket['normalized_gemini_flash_lite_25_hpo_ids'] =='-'].shape[0]
# Out:
# 7858
